# %% [markdown]
# # Q.1 Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Q.2 Get the Dataset

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# # Q3. Plot the distribution of total_bill in the given dataset.

# %%
sns.pointplot(df["size"], df["tip"])

# %% [markdown]
# # Q.4 - Plot the destribution plot for tips.

# %%
sns.distplot(df["tip"])

# %% [markdown]
# # Q5. Make a joint plot between tip and total bill.

# %%
sns.jointplot(df["tip"], df["total_bill"])

# %% [markdown]
# # Q6. Give additional attribute kind = "hex" in the above plot.

# %%
sns.jointplot(df["tip"], df["total_bill"], kind="hex")

# %% [markdown]
# # Q7. Make pairplot between total bill and tip.

# %%
sns.pairplot(df[["total_bill", "tip"]])

# %% [markdown]
# # Q.8 -  Make striplot between sex and tip.

# %%
sns.stripplot(df["sex"], df["tip"], jitter=True)

# %% [markdown]
# # Q.9 - What other plots you can make for tip and sex variable.Plot them.

# %%
sns.swarmplot(df["sex"], df["tip"])

# %% [markdown]
# # Q.10 Make bar plot with day and total bill.

# %%
sns.boxplot(df["sex"], df["tip"])

# %% [markdown]
# # Q.11 - Make a plot to count total males and females for each day.

# %%
sns.countplot(df["sex"], hue=df["day"])

# %% [markdown]
# # Q.12 -  Use factorplot to plot multiple categorical variables like day, smoker, peoplecount.

# %%
sns.catplot(x="day", y="size", hue="smoker", data=df, kind="box")

# %% [markdown]
# # Q.13 - Use lmplot() to plot the relation between total bill and tip.

# %%
sns.lineplot(x="total_bill", y="tip", data=df)

# %% [markdown]
# # Q.14 - Plot the above graph for male and female.

# %%
df["sex"] = df["sex"].astype('category')
df["sex"] = df["sex"].cat.codes #0=Male, 1= Female
sns.lmplot(x="sex", y="tip", data=df)

# %% [markdown]
# # Q.14 - Plot the Q.13 graph for smoker and non-smoker.

# %%
sns.lmplot(x="smoker", y="tip", data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-8a928863e5c2> in <module>
# ----> 1 sns.lmplot(x="smoker", y="tip", data=df)
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     587         scatter_kws=scatter_kws, line_kws=line_kws,
#     588         )
# --> 589     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     590
#     591     # Add a legend
#
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
#     819             # Draw the plot
# --> 820             self._facet_plot(func, ax, args, kwargs)
#     821
#     822         # Finalize the annotations and layout
#
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     787     scatter_kws["marker"] = marker
#     788     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 789     plotter.plot(ax, scatter_kws, line_kws)
#     790     return ax
#     791
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     342             self.scatterplot(ax, scatter_kws)
#     343         if self.fit_reg:
# --> 344             self.lineplot(ax, line_kws)
#     345
#     346         # Label the axes
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     387
#     388         # Fit the regression model
# --> 389         grid, yhat, err_bands = self.fit_regression(ax)
#     390
#     391         # Get set default aesthetics
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     206             yhat, yhat_boots = self.fit_logx(grid)
#     207         else:
# --> 208             yhat, yhat_boots = self.fit_fast(grid)
#     209
#     210         # Compute the confidence interval at each grid point
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in fit_fast(self, grid)
#     223         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#     224         grid = np.c_[np.ones(len(grid)), grid]
# --> 225         yhat = grid.dot(reg_func(X, y))
#     226         if self.ci is None:
#     227             return yhat, None
#
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py in reg_func(_x, _y)
#     219         """Low-level regression and prediction using linear algebra."""
#     220         def reg_func(_x, _y):
# --> 221             return np.linalg.pinv(_x).dot(_y)
#     222
#     223         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#
# /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py in pinv(a, rcond)
#    1935         res = empty(a.shape[:-2] + (n, m), dtype=a.dtype)
#    1936         return wrap(res)
# -> 1937     a = a.conjugate()
#    1938     u, s, vt = svd(a, full_matrices=False)
#    1939
#
# AttributeError: 'str' object has no attribute 'conjugate'
